# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
from sklearn.utils import shuffle
import numpy as np
import cv2
import os
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
def read_data(data_path):
    dataset = []
    labels = []
    DIRPATH = os.listdir(data_path)
    for i in range(len(DIRPATH)):
        for img in os.listdir(os.path.join(data_path, DIRPATH[i])):
            image = np.mean(cv2.imread(os.path.join(data_path, DIRPATH[i], img))) // 255
            # Resize the image to a consistent shape
            image = cv2.resize(image, (255, 255))
            dataset.append(image)
            labels.append(i)
    return np.array(dataset, dtype=np.float32), np.array(labels, dtype=np.int64)
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
datapath = '/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone'
data, label = read_data(datapath)
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
len(data), len(label)
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
data, labels = shuffle(data, label)
labels[0], data[0].shape
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
training_data, testing_data = data[:int(len(data)*0.95)], data[int(len(data)*0.95)+1:]
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
training_labels, testing_labels = labels[:int(len(labels)*0.95)], labels[int(len(labels)*0.95)+1:]
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
training_labels[:5]
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
print(type(training_data), type(testing_labels))
print(training_data.shape, testing_labels.shape)
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(255, 255, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
model.summary()
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
model.fit(training_data, training_labels, shuffle=True, validation_data=(testing_data, testing_labels), epochs=10, batch_size=64)
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
model.save('kidney.h5')
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Projects/Federated-Leraning-Medical-Assistant/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
